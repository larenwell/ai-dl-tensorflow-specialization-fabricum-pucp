# %% [markdown]
# <div align="center">
#
# <img src="https://s3.amazonaws.com/files.pucp.edu.pe/pucp-general/img-header/logo-pucp-new.svg" alt="Pontificia Universidad Católica del Perú">
#
# <br><br>
#
# ## Pontificia Universidad Católica del Perú
#
# ### Deep Learning con Python
#
# <br>
#
# ## Semana 1 — Tarea 1
#
# ### Fundamentos de python y creacion de un dataset
#
# </div>
#
# ---
#
# Objetivo de este notebook:
#
# - Repasar y aplicar los principales fundamentos de python
#
# - Desarrollar el codigo para generar un dataset normalizado

# %% [markdown]
# # Problema 1: Sistema de Reservas de Hotel
#
# Una cadena de hoteles almacena su información en una lista de diccionarios
# con el siguiente formato:
#
# habitaciones = [
#
#     {"ciudad": "Lima", "tipo": "Simple", "precio": 120, "disponibles": 5},
#
#     {"ciudad": "Lima", "tipo": "Doble", "precio": 180, "disponibles": 3},
#
#     {"ciudad": "Cusco", "tipo": "Simple", "precio": 150, "disponibles": 4},
#
#     {"ciudad": "Cusco", "tipo": "Suite", "precio": 300, "disponibles": 2},
#
#     {"ciudad": "Arequipa", "tipo": "Doble", "precio": 160, "disponibles": 6}
# ]
#
#
# Se pide implementar las siguientes funciones:
#
# ---

# %%
habitaciones = [
    {"ciudad": "Lima", "tipo": "Simple", "precio": 120, "disponibles": 5},
    {"ciudad": "Lima", "tipo": "Doble", "precio": 180, "disponibles": 3},
    {"ciudad": "Cusco", "tipo": "Simple", "precio": 150, "disponibles": 4},
    {"ciudad": "Cusco", "tipo": "Suite", "precio": 300, "disponibles": 2},
    {"ciudad": "Arequipa", "tipo": "Doble", "precio": 160, "disponibles": 6}
]

# %% [markdown]
# 1️⃣ habitaciones_disponibles(habitaciones, ciudad, cantidad)
#
# Debe retornar una lista de habitaciones disponibles en una ciudad
# que tengan al menos la cantidad solicitada.

# %% [markdown]
# 2️⃣ habitacion_mas_barata(habitaciones, ciudad)
#
# Debe retornar la habitación más barata disponible en la ciudad indicada.

# %% [markdown]
# 3️⃣ aplicar_descuento_ciudad(habitaciones, ciudad, porcentaje)
#
# Debe aplicar un descuento (porcentaje) a todas las habitaciones
# de una ciudad específica.
#
# El precio debe actualizarse directamente en la estructura de datos.

# %% [markdown]
# 4️⃣ reservar_habitacion(habitaciones, ciudad, tipo, cantidad)
#
# Debe descontar la cantidad de habitaciones disponibles si existe suficiente disponibilidad.
# Si no hay disponibilidad suficiente, debe mostrar un mensaje indicando el problema.

# %% [markdown]
# # Problema 2: Programación Orientada a Objetos – Sistema RPG
#
# En este problema implementaremos un pequeño sistema inspirado en un videojuego.
#
# ---

# %% [markdown]
# 1️⃣ Clase Personaje
#
# Crear una clase llamada `Personaje` que:
#
# - Reciba en el constructor:
#   - nombre (str)
#   - vida (int)
#   - ataque (int)
#
# - Guarde estos valores como atributos.

# %% [markdown]
# 2️⃣ Método recibir_daño
#
# Agregar un método llamado `recibir_daño(self, cantidad)` que:
#
# - Reste la cantidad recibida a la vida.
# - La vida nunca puede ser menor que 0.

# %% [markdown]
# 3️⃣ Método atacar
#
# Agregar un método llamado `atacar(self, otro_personaje)` que:
#
# - Use el atributo `ataque`
# - Llame al método `recibir_daño` del otro personaje

# %% [markdown]
# 4️⃣ Método especial __str__
#
# Implementar el método `__str__` para que al imprimir el objeto se muestre:
#
# Personaje: <nombre> | Vida: <vida> | Ataque: <ataque>

# %% [markdown]
# 5️⃣ Simulación
#
# Crear dos personajes y simular un pequeño combate
# mostrando el estado de cada uno después de los ataques.

# %% [markdown]
# # Problema 3: Análisis de Ventas de una Tienda
#
# En este laboratorio trabajaremos con:
#
# - NumPy → operaciones numéricas
# - Pandas → manipulación de datos
# - Matplotlib → visualización
#
# Imaginemos que tenemos información de ventas diarias
# de una tienda durante 30 días.
#
# ---

# %% [markdown]
# Generación de datos con NumPy
#
# 1️⃣ Cree un arreglo de 30 números aleatorios entre 50 y 200
# que representen las ventas diarias.
#
# Use:
#
# np.random.randint()

# %% [markdown]
# 2️⃣ Calcule:
#
# - Venta promedio
# - Venta máxima
# - Venta mínima
# - Desviación estándar
#
# Muestre los resultados en pantalla.

# %% [markdown]
# 3️⃣ Cree un DataFrame que tenga dos columnas:
#
# - "Dia" → valores del 1 al 30
# - "Ventas" → el arreglo generado

# %% [markdown]
# 4️⃣ Muestre:
#
# - Las primeras 5 filas
# - Estadísticas generales usando describe()

# %% [markdown]
# 5️⃣ Cree una nueva columna llamada:
#
# "Categoria"
#
# Donde:
#
# - "Alta" si la venta es mayor al promedio
# - "Baja" si la venta es menor o igual al promedio

# %% [markdown]
# 6️⃣ Calcule cuántos días fueron:
#
# - Alta
# - Baja

# %% [markdown]
# 7️⃣ Grafique:
#
# - Un gráfico de línea (ventas por día)
# - Un gráfico de barras mostrando la cantidad de días Alta vs Baja
#
# Agregue:
#
# - Título
# - Etiquetas en los ejes

# %% [markdown]
# # Problema 4 – Construcción de Dataset: Fruits vs Non-Fruits
#
# En este laboratorio construiremos un dataset desde cero
# para un problema de clasificación binaria:
#
# 🍎 Clase 1 → Fruit
# 🚫 Clase 0 → Non-Fruit
#
# El objetivo es replicar el pipeline visto en clase:
# - Descarga automática
# - Organización por carpetas
# - Redimensionamiento
# - Construcción de etiquetas
# - Verificación visual
#
# ---

# %% [markdown]
# Descarga de imágenes
#
# 1️⃣ Descargue imágenes reales de frutas utilizando al menos 3 consultas diferentes.
#
# Ejemplo de consultas:
# - "single apple on white background"
# - "real banana isolated"
# - "fresh orange fruit photo"
#
# Descargue al menos 40 imágenes por consulta.

# %% [markdown]
# 2️⃣ Descargue imágenes que NO sean frutas.
#
# Ejemplo:
# - "real car isolated"
# - "modern chair product photo"
# - "house exterior photo"
#
# Descargue al menos 40 imágenes por consulta.

# %% [markdown]
# Parte 2 – Organización del dataset
#
# 3️⃣ Cree la siguiente estructura:
#
#
# dataset_fruits/
#
#     fruit/
#
#     non_fruit/

# %% [markdown]
# 4️⃣ Mueva las imágenes descargadas a su carpeta correspondiente
# y renómbrelas de forma secuencial:
#
# fruit_0.jpg, fruit_1.jpg, ...
# non_fruit_0.jpg, non_fruit_1.jpg, ...

# %% [markdown]
# Parte 3 – Redimensionamiento
#
# 5️⃣ Redimensione todas las imágenes a:
#
# 128x128 píxeles
#
# Guarde el resultado en:
#
# dataset_fruits_resized/
#
# Mantenga la estructura por clases.

# %% [markdown]
# Parte 4 – Construcción del dataset supervisado
#
# 6️⃣ Recorra las carpetas y construya:
#
# - Una lista llamada image_paths
# - Una lista llamada labels
#
# Donde:
# - fruit → etiqueta 1
# - non_fruit → etiqueta 0

# %% [markdown]
# Parte 5 – Verificación visual
#
# 7️⃣ Muestre 3 imágenes aleatorias junto con su etiqueta.
