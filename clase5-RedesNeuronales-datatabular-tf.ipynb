# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import classification_report

# %%
import os
print(os.getcwd())
# Out:
# /Users/larenwell/Documents/personal/projects/ai-dl-tensorflow-specialization-fabricum-pucp

# %%
df = pd.read_csv("WaterQuality1.csv")

# %%
df.head()
# Out:
#    aluminium ammonia  arsenic  barium  cadmium  chloramine  chromium  copper  \
# 0       1.65    9.08     0.04    2.85    0.007        0.35      0.83    0.17
# 1       2.32   21.16     0.01    3.31    0.002        5.28      0.68    0.66
# 2       1.01   14.02     0.04    0.58    0.008        4.24      0.53    0.02
# 3       1.36   11.33     0.04    2.96    0.001        7.23      0.03    1.66
# 4       0.92   24.33     0.03    0.20    0.006        2.67      0.69    0.57
#
#    flouride  bacteria  ...   lead  nitrates  nitrites  mercury  perchlorate  \
# 0      0.05      0.20  ...  0.054     16.08      1.13    0.007        37.75
# 1      0.90      0.65  ...  0.100      2.01      1.93    0.003        32.26
# 2      0.99      0.05  ...  0.078     14.16      1.11    0.006        50.28
# 3      1.08      0.71  ...  0.016      1.41      1.29    0.004         9.12
# 4      0.61      0.13  ...  0.117      6.74      1.11    0.003        16.90
#
#    radium  selenium  silver  uranium  is_safe
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7999 entries, 0 to 7998
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   aluminium    7999 non-null   float64
#  1   ammonia      7999 non-null   str
#  2   arsenic      7999 non-null   float64
#  3   barium       7999 non-null   float64
#  4   cadmium      7999 non-null   float64
#  5   chloramine   7999 non-null   float64
#  6   chromium     7999 non-null   float64
#  7   copper       7999 non-null   float64
#  8   flouride     7999 non-null   float64
#  9   bacteria     7999 non-null   float64
#  10  viruses      7999 non-null   float64
#  11  lead         7999 non-null   float64
#  12  nitrates     7999 non-null   float64
#  13  nitrites     7999 non-null   float64
#  14  mercury      7999 non-null   float64
#  15  perchlorate  7999 non-null   float64
#  16  radium       7999 non-null   float64
#  17  selenium     7999 non-null   float64
# ...

# %%
df.replace('#NUM!',np.nan,inplace=True)
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 7996 entries, 0 to 7998
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   aluminium    7996 non-null   float64
#  1   ammonia      7996 non-null   str
#  2   arsenic      7996 non-null   float64
#  3   barium       7996 non-null   float64
#  4   cadmium      7996 non-null   float64
#  5   chloramine   7996 non-null   float64
#  6   chromium     7996 non-null   float64
#  7   copper       7996 non-null   float64
#  8   flouride     7996 non-null   float64
#  9   bacteria     7996 non-null   float64
#  10  viruses      7996 non-null   float64
#  11  lead         7996 non-null   float64
#  12  nitrates     7996 non-null   float64
#  13  nitrites     7996 non-null   float64
#  14  mercury      7996 non-null   float64
#  15  perchlorate  7996 non-null   float64
#  16  radium       7996 non-null   float64
#  17  selenium     7996 non-null   float64
# ...

# %% [markdown]
# Definición del dataset de entrenamiento

# %%
X=df.drop("is_safe",axis=1) #axis 1 para columnas, axis 0 para filas
y=df["is_safe"]

# %% [markdown]
# Pre-processing

# %%
label_encoder = LabelEncoder()
scaler = StandardScaler()

# %%
col_originales = X.columns

# %%
X_scaled = scaler.fit_transform(X)
y_encoded = label_encoder.fit_transform(y)

# Se emplea StandardScaler para normalizar los datos cuando se tiene una distribución normal-
# Se emplea MinMaxScaler para normalizar los datos cuando se tiene una distribución no normal.

# %%
X_scaled
# Out:
# array([[ 0.77740287, -0.58549134, -0.48087476, ...,  1.05369443,
#          1.33873624, -0.91704015],
#        [ 1.30694501,  0.77511802, -0.59963176, ...,  1.05369443,
#          0.85113427,  0.19802266],
#        [ 0.27157158, -0.02908321, -0.48087476, ...,  0.70612871,
#          2.03531047, -1.28872776],
#        ...,
#        [-0.45556091, -0.83666343, -0.63921743, ..., -1.72683135,
#         -0.75098648,  0.19802266],
#        [-0.51878982, -0.48186877, -0.59963176, ..., -1.72683135,
#         -1.02961617, -1.66041536],
#        [-0.49507898, -0.83666343, -0.59963176, ..., -1.72683135,
#         -0.75098648,  0.19802266]], shape=(7996, 20))

# %%
y_encoded
# Out:
# array([1, 1, 0, ..., 1, 1, 1], shape=(7996,))

# %%
x_train, x_test, y_train, y_test = train_test_split(X_scaled, y_encoded, test_size=0.2, random_state=42)

# %%
x_train,x_val,y_train,y_val = train_test_split(x_train,y_train,test_size=0.2,random_state=42)

# %%
model1=tf.keras.Sequential([
    tf.keras.layers.Dense(128, input_shape=(x_train.shape[1])
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model1.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 from tensorflow.keras.models import layers
#       2 from tensorflow.keras.models import Sequential
#       3 from tensorflow.keras.models import Dense
#
# ImportError: cannot import name 'layers' from 'tensorflow.keras.models' (/Users/larenwell/Documents/personal/projects/ai-dl-tensorflow-specialization-fabricum-pucp/.venv/lib/python3.12/site-packages/keras/_tf_keras/keras/models/__init__.py)

# %% [markdown]
# ¿Que hace batchnormalization?

# %% [markdown]
# ¿Que pasa cuando no se activa la función de activación?
#
# Mirar la grabación en el minuto 20:18.
# - No se emplea inicialmente Relu entonces por defecto se emplea Lineal
# - No se emplea sigmoide en la capa de salida, entonces sale un valor de probabilidad, lo que hizo el profesor fue luego utilizar el sigmoid para obtener el valor de 0 o 1.

# %% [markdown]
# ¿? El tema del classweight, que hace internamente?
#
# Dentro de la función de perdida le pongo un factor mayor a la clase minoritaria con ello le doy un mayor castigo a la clase minitoria, para que el modelo ajustar mejor sus parametros para la clase minoritaria.
#
# Otros casos:
# Dar más peso a la clase minoritaria, crear datos sinteticos, como data augmentation en imágenes..
