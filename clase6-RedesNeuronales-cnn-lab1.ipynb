# %% [markdown]
# Clase 6

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import random
from tensorflow.keras.datasets import cifar10

# %%
import ssl

ssl._create_default_https_context=ssl._create_unverified_context

# %%
#(x_train,y_train),(x_test,y_test)=cifar10.load_data()

# %%
x_train =x_train/255.0
x_test=x_test/255.0

# %%
# Permite normalizar, ya que cada valor de RGB va hasta 255.

# %%
x_train = x_train.reshape(-1,32*32*3)
x_train = x_train.reshape(-1,32*32*3)

# Para que se realiza esto?
# Permite tener un vector unidimensional de 3072 columnas
# Los 5000 ejemplos siguen siendo los mismos.

# Esto se declara en input_shape de la capa inicial.

# %%
# to_categorical permite realizar un reshape respetando la clase categorica.

# %% [markdown]
# CNN

# %%
# Con CNN ya vemos otros detalles
# Los filtros irán aprendiendo
# Incluso detalles que nosotros no podemos reconocer del todo

# %%
#  no conviene tener dimensiones iniciales de kernels
# porque puede ser que no pueda reconocer algunos detalles? Esto es cierto?
# La pregunta es como debo 
# 128 es un numero hiperparametro que se necesita entrenar.

# %% [markdown]
# OTRAS REDES CLASICAS

# %% [markdown]
# - ALEXNET
# - VGG-16
# - RESNET 50: Conexiones Residuales.
# - Inception UV3.
# - EfficientNEtB0
#
#
# dataset: Imagenet.

# %% [markdown]
# TRANSFERENCIA DE APRENDIZAJE

# %% [markdown]
# - Permite aprovechar algunas capas profundas debidamente ya entrenadas.
# - En el TL se reutilizan capas.
# - Dos tecnicas: Feature Extraction y Fine Tunning.

# %% [markdown]
# import tensorflow as tf

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
train_dataset = tf.keras.utils.image_dataset_from_directory(
    'dataset_alpacas/',
    shuffle=True,
    batch_size=32,
    imagen_size=(299,299),
    


)

# %%
# Se debe revisar estos casos.
